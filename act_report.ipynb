# %% [markdown]
# # Act Report : WeRateDogs Twitter Data
# This report communicates the insights and displays the visualization produced from the wrangled data.

# %% [markdown]
# ## Which source is used to tweet the most?

# %% [markdown]
# ![Tweet Source](data:image/png;base64,... "Tweet Source")

# %% [markdown]
# The source that is mostly used to tweet is **Twitter for iPhone**. Through this it is same to assume that Twitter users prefer to tweet from their iPhones than to use other tweet sources like **TweetDeck, Twitter Web Client and Vine - Make a Scene

# %% [markdown]
# ## Trend of retweets overtime?

# %% [markdown]
# I got curious about the trend of retweets and likes over the period of the data. I wondered if the trend of _retweets_ will match with the trend of _likes_. Hence, I decided to look at both the rewteets and likes separately then I checked their correlation.

# %% [markdown]
# ![Trend of Retweets](data:image/png;base64,... "Trend of Retweets")

# %% [markdown]
# **Retweets** were higher between `June 2016` and `July 2016` with approximately 7000 retweets, and went on a significant decrease until the `December 2016` and `January 2017`

# %% [markdown]
# ## Trend of likes overtime?

# %% [markdown]
# ![likes](data:image/png;base64,... "likes")

# %% [markdown]
# Pictorially, **likes** seem to share similar trends as **retweets** but while the increased retweets occurred between `December 2016` and `January 2017`, the increased likes extended to `February 2017` and decreased in `March 2017`, just as retweets.
#
# Looking at the two timeseries display above, it can be deduced that retweet count and favorite count share a significant positive correlation. The scatter plot below shows this.

# %% [markdown]
# ## What kind of relationship is between favorite count and retweet count?

# %% [markdown]
# ![scatter plot](data:image/png;base64,... "scatter plot")

# %% [markdown]
# It is evident that as retweets increase, so does likes and vice versa. Hence the significant _**upward movement**_ of the plot.

# %% [markdown]
# ## Which dog stage are most dogs at?

# %% [markdown]
# ![dog stage](data:image/png;base64,... "dog stage")

# %% [markdown]
# The bar chart above shows that most of the dogs are at the **puppo stage**. _Puppo_ is used to refer to puppies. I also queried the data for the most popular dog names.

# %% [markdown]
# ## What are the top 10 dog names?
#
# I displayed the top **ten (10)** common names given to dogs below using the barh chart.

# %% [markdown]
# ![dog names](data:image/png;base64,... "dog names")

# %% [markdown]
# Through my analysis and visualization efforts I have been able to answer the questions below:
#
# * Which source is used to tweet the most?
# * Trend of retweets overtime?
# * Trend of tweet likes overtime?
# * What kind of relationship is between favorite count and retweet count?
# * Which dog stage are most dogs at?
# * What are the top 10 dog names?
#
# The code is in the **Visualization** subsection in the **‘Analyzing and Visualizing Data’** section of the `wrangle_act.ipynb notebook`.
